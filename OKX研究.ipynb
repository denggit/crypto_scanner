# %%
import os
import sys
from dotenv import load_dotenv
from okx_api.client import OKXClient
from okx_api.market_data import MarketDataRetriever
from tools.market_scanner import CryptoScanner
from tools.strategy_1 import EMACrossoverStrategy

load_dotenv()
# Out:
# True

# %%
client = OKXClient(
    api_key=os.getenv("OK-ACCESS-KEY"),
    api_secret=os.getenv("OK-ACCESS-SECRET"),
    passphrase=os.getenv("OK-ACCESS-PASSPHRASE")
)

# Initialize market data retriever
market_data = MarketDataRetriever(client)

# Initialize crypto scanner
crypto_scanner = CryptoScanner(client)

# Initialize strategy 1
strat_1 = EMACrossoverStrategy(client)

# %%
market_data.client.get_tickers()
# Out:
# {'code': '0',
#  'msg': '',
#  'data': [{'instType': 'SPOT',
#    'instId': 'ILV-USD',
#    'last': '14.807',
#    'lastSz': '1.088876',
#    'askPx': '14.527',
#    'askSz': '20.651201',
#    'bidPx': '14.352',
#    'bidSz': '28.567447',
#    'open24h': '14.292',
#    'high24h': '16.223',
#    'low24h': '14.292',
#    'volCcy24h': '5889.665948058',
#    'vol24h': '381.097502',
#    'ts': '1760125704512',
#    'sodUtc0': '14.339',
#    'sodUtc8': '14.807'},
#   {'instType': 'SPOT',
#    'instId': '1INCH-EUR',
#    'last': '0.206',
#    'lastSz': '96.680947',
#    'askPx': '0.2061',
#    'askSz': '527.050998',
#    'bidPx': '0.2055',
#    'bidSz': '34.3249',
#    'open24h': '0.2154',
#    'high24h': '0.2199',
#    'low24h': '0.204',
#    'volCcy24h': '2462.468837767',
#    'vol24h': '11708.993649',
#    'ts': '1760125725226',
#    'sodUtc0': '0.2156',
#    'sodUtc8': '0.2115'},
#   {'instType': 'SPOT',
#    'instId': 'CHZ-USD',
#    'last': '0.039',
#    'lastSz': '0.084',
#    'askPx': '0.03942',
#    'askSz': '6343.54258',
#    'bidPx': '0.03938',
#    'bidSz': '6349.054626',
#    'open24h': '0.04135',
#    'high24h': '0.0416',
#    'low24h': '0.039',
#    'volCcy24h': '3855.86560477843',
#    'vol24h': '93853.191589',
#    'ts': '1760125725216',
#    'sodUtc0': '0.04159',
#    'sodUtc8': '0.04044'},
#   {'instType': 'SPOT',
#    'instId': 'DAO-USD',
#    'last': '0.1082',
#    'lastSz': '172.627567',
#    'askPx': '0.1035',
#    'askSz': '455.479225',
#    'bidPx': '0.1016',
#    'bidSz': '1047.998347',
#    'open24h': '0.1092',
#    'high24h': '0.1092',
#    'low24h': '0.1082',
#    'volCcy24h': '18.6783027494',
#    'vol24h': '172.627567',
#    'ts': '1760125703811',
#    'sodUtc0': '0.1082',
#    'sodUtc8': '0.1082'},
#   {'instType': 'SPOT',
#    'instId': 'OAS-USDT',
#    'last': '0.00744',
#    'lastSz': '250.29',
#    'askPx': '0.00744',
#    'askSz': '10575.85',
#    'bidPx': '0.00741',
#    'bidSz': '25165.78',
#    'open24h': '0.00801',
#    'high24h': '0.00818',
#    'low24h': '0.00739',
#    'volCcy24h': '90065.3883502',
#    'vol24h': '11399471.4',
#    'ts': '1760125709820',
#    'sodUtc0': '0.00808',
#    'sodUtc8': '0.00767'},
#   {'instType': 'SPOT',
#    'instId': 'MASK-USD',
#    'last': '1.231',
#    'lastSz': '39.297375',
#    'askPx': '1.187',
#    'askSz': '324.493427',
#    'bidPx': '1.174',
#    'bidSz': '1301.086555',
#    'open24h': '1.231',
#    'high24h': '1.231',
#    'low24h': '1.231',
#    'volCcy24h': '0',
#    'vol24h': '0',
#    'ts': '1760125708970',
#    'sodUtc0': '1.231',
#    'sodUtc8': '1.231'},
#   {'instType': 'SPOT',
#    'instId': 'ORBS-USD',
#    'last': '0.01615',
#    'lastSz': '2767.180554',
#    'askPx': '0.0154',
#    'askSz': '19480.51948',
#    'bidPx': '0.01524',
#    'bidSz': '33969.157871',
#    'open24h': '0.01615',
#    'high24h': '0.01615',
#    'low24h': '0.01615',
#    'volCcy24h': '0',
#    'vol24h': '0',
#    'ts': '1760125680028',
#    'sodUtc0': '0.01615',
#    'sodUtc8': '0.01615'},
#   {'instType': 'SPOT',
#    'instId': 'KNC-USDT',
#    'last': '0.3105',
#    'lastSz': '383.32361',
#    'askPx': '0.3123',
#    'askSz': '2402.306213',
#    'bidPx': '0.3116',
#    'bidSz': '2405.002405',
#    'open24h': '0.3262',
#    'high24h': '0.3327',
#    'low24h': '0.3077',
#    'volCcy24h': '39917.3254540082',
#    'vol24h': '123826.495811',
#    'ts': '1760125686723',
#    'sodUtc0': '0.3279',
#    'sodUtc8': '0.3169'},
#   {'instType': 'SPOT',
#    'instId': 'IOTA-USDC',
#    'last': '0.1712',
#    'lastSz': '2471.87',
#    'askPx': '0.1712',
#    'askSz': '2920.56',
#    'bidPx': '0.1707',
#    'bidSz': '2929.11',
#    'open24h': '0.1828',
#    'high24h': '0.185',
#    'low24h': '0.1689',
#    'volCcy24h': '83246.282974',
#    'vol24h': '465862.01',
#    'ts': '1760125725034',
#    'sodUtc0': '0.1828',
#    'sodUtc8': '0.1737'},
#   {'instType': 'SPOT',
#    'instId': 'TRUMP-USDT',
#    'last': '7.15',
#    'lastSz': '19.2628',
#    'askPx': '7.151',
#    'askSz': '54.9002',
#    'bidPx': '7.15',
#    'bidSz': '101.1939',
#    'open24h': '7.493',
#    'high24h': '7.594',
#    'low24h': '7.02',
#    'volCcy24h': '22172996.0637706',
#    'vol24h': '3014385.3271',
#    'ts': '1760125726748',
#    'sodUtc0': '7.534',
#    'sodUtc8': '7.204'},
#   {'instType': 'SPOT',
#    'instId': 'STETH-USD',
#    'last': '3947.34',
#    'lastSz': '0.012428',
#    'askPx': '4055.94',
#    'askSz': '0.073965',
#    'bidPx': '4016.02',
#    'bidSz': '0.102091',
#    'open24h': '4290.22',
#    'high24h': '4350.62',
#    'low24h': '3947.34',
#    'volCcy24h': '482.88530618',
#    'vol24h': '0.117767',
#    'ts': '1760125725919',
#    'sodUtc0': '4350.62',
#    'sodUtc8': '3947.34'},
#   {'instType': 'SPOT',
#    'instId': 'LAYER-USD',
#    'last': '0.3664',
#    'lastSz': '356.331',
#    'askPx': '0.3657',
#    'askSz': '69.46',
#    'bidPx': '0.3617',
#    'bidSz': '9180.432',
#    'open24h': '0.416',
#    'high24h': '0.416',
#    'low24h': '0.3664',
#    'volCcy24h': '194.3349324',
#    'vol24h': '518.609',
#    'ts': '1760125725514',
#    'sodUtc0': '0.393',
#    'sodUtc8': '0.3664'},
#   {'instType': 'SPOT',
#    'instId': 'SSV-USD',
#    'last': '8.104',
#    'lastSz': '12.5997',
#    'askPx': '7.52',
#    'askSz': '22.6519',
#    'bidPx': '7.461',
#    'bidSz': '445.4602',
#    'open24h': '7.717',
#    'high24h': '8.104',
#    'low24h': '7.717',
#    'volCcy24h': '113.1204944',
#    'vol24h': '13.9586',
#    'ts': '1760125720934',
#    'sodUtc0': '8.104',
#    'sodUtc8': '8.104'},
#   {'instType': 'SPOT',
#    'instId': 'BOME-USDT',
#    'last': '0.001477',
#    'lastSz': '4692',
#    'askPx': '0.001483',
#    'askSz': '106720',
#    'bidPx': '0.001482',
#    'bidSz': '555484',
#    'open24h': '0.001614',
#    'high24h': '0.001663',
#    'low24h': '0.001452',
#    'volCcy24h': '911374.491965',
#    'vol24h': '582061918',
#    'ts': '1760125726410',
#    'sodUtc0': '0.001626',
#    'sodUtc8': '0.001518'},
#   {'instType': 'SPOT',
#    'instId': 'RESOLV-USDT',
#    'last': '0.091',
#    'lastSz': '10',
#    'askPx': '0.0913',
#    'askSz': '7236.14',
#    'bidPx': '0.0912',
#    'bidSz': '7875.54',
#    'open24h': '0.0978',
#    'high24h': '0.1017',
#    'low24h': '0.0889',
#    'volCcy24h': '2064315.592198',
#    'vol24h': '21337531.3',
#    'ts': '1760125723915',
#    'sodUtc0': '0.0979',
#    'sodUtc8': '0.0929'},
#   {'instType': 'SPOT',
#    'instId': 'DAI-USDT',
#    'last': '0.9995',
#    'lastSz': '200.05',
#    'askPx': '0.9996',
#    'askSz': '6397.973474',
#    'bidPx': '0.9995',
#    'bidSz': '3842.135216',
#    'open24h': '0.9993',
#    'high24h': '1.0002',
#    'low24h': '0.9971',
#    'volCcy24h': '1887255.2574171981',
#    'vol24h': '1888173.818504',
#    'ts': '1760125695122',
#    'sodUtc0': '0.9993',
#    'sodUtc8': '0.9997'},
#   {'instType': 'SPOT',
#    'instId': 'LUNA-USDT',
#    'last': '0.1275',
#    'lastSz': '189.6455',
#    'askPx': '0.1275',
#    'askSz': '689.6163',
#    'bidPx': '0.1274',
#    'bidSz': '362.7348',
#    'open24h': '0.1335',
#    'high24h': '0.1363',
#    'low24h': '0.1247',
#    'volCcy24h': '379437.67671377',
#    'vol24h': '2899057.5609',
#    'ts': '1760125725510',
#    'sodUtc0': '0.1347',
#    'sodUtc8': '0.1287'},
#   {'instType': 'SPOT',
#    'instId': 'PYTH-USD',
#    'last': '0.14292',
#    'lastSz': '1050',
#    'askPx': '0.14383',
#    'askSz': '1050',
#    'bidPx': '0.14362',
#    'bidSz': '1050',
#    'open24h': '0.15439',
#    'high24h': '0.15866',
#    'low24h': '0.14184',
#    'volCcy24h': '48515.83592912',
#    'vol24h': '318309.357',
#    'ts': '1760125721915',
#    'sodUtc0': '0.15524',
#    'sodUtc8': '0.14664'},
#   {'instType': 'SPOT',
#    'instId': 'AEVO-USD',
#    'last': '0.09182',
#    'lastSz': '2543.1703',
#    'askPx': '0.0926',
#    'askSz': '4656.6726',
#    'bidPx': '0.09193',
#    'bidSz': '4459.9151',
#    'open24h': '0.0961',
#    'high24h': '0.0961',
#    'low24h': '0.09182',
#    'volCcy24h': '233.519513288',
#    'vol24h': '2543.2306',
#    'ts': '1760125726911',
#    'sodUtc0': '0.09314',
#    'sodUtc8': '0.09182'},
#   {'instType': 'SPOT',
#    'instId': 'SPK-USDT',
#    'last': '0.04642',
#    'lastSz': '741.9',
#    'askPx': '0.04653',
#    'askSz': '2323.3',
#    'bidPx': '0.04651',
#    'bidSz': '242.4',
#    'open24h': '0.0469',
#    'high24h': '0.05058',
#    'low24h': '0.04555',
#    'volCcy24h': '2022776.074353',
#    'vol24h': '41538658.3',
#    'ts': '1760125721126',
#    'sodUtc0': '0.04876',
#    'sodUtc8': '0.04771'},
#   {'instType': 'SPOT',
#    'instId': 'XRP-USD',
#    'last': '2.6895',
#    'lastSz': '264.7',
#    'askPx': '2.6893',
#    'askSz': '114.08331',
#    'bidPx': '2.6892',
#    'bidSz': '371.907',
#    'open24h': '2.7855',
#    'high24h': '2.8377',
#    'low24h': '2.6356',
#    'volCcy24h': '6200414.7464966911',
#    'vol24h': '2247620.7184',
#    'ts': '1760125726921',
#    'sodUtc0': '2.8036',
#    'sodUtc8': '2.7404'},
#   {'instType': 'SPOT',
#    'instId': 'PI-USDT',
#    'last': '0.2324',
#    'lastSz': '204.835',
#    'askPx': '0.2323',
#    'askSz': '1467.612',
#    'bidPx': '0.2322',
#    'bidSz': '12095.621',
#    'open24h': '0.2279',
#    'high24h': '0.2394',
#    'low24h': '0.225',
#    'volCcy24h': '14818321.2076413',
#    'vol24h': '63929859.438',
#    'ts': '1760125725424',
#    'sodUtc0': '0.2295',
#    'sodUtc8': '0.2291'},
#   {'instType': 'SPOT',
#    'instId': 'AGLD-USDT',
#    'last': '0.5181',
#    'lastSz': '138',
#    'askPx': '0.5179',
#    'askSz': '66.309797',
#    'bidPx': '0.5174',
#    'bidSz': '432.566902',
#    'open24h': '0.5476',
#    'high24h': '0.5629',
#    'low24h': '0.5096',
#    'volCcy24h': '310285.4605405088',
#    'vol24h': '577740.363094',
#    'ts': '1760125726513',
#    'sodUtc0': '0.5529',
#    'sodUtc8': '0.5276'},
#   {'instType': 'SPOT',
#    'instId': 'CVX-USDT',
#    'last': '3.027',
#    'lastSz': '2',
#    'askPx': '3.042',
#    'askSz': '15.561728',
#    'bidPx': '3.039',
#    'bidSz': '195.790504',
#    'open24h': '3.232',
#    'high24h': '3.307',
#    'low24h': '2.98',
#    'volCcy24h': '463546.652669145',
#    'vol24h': '146069.247327',
#    'ts': '1760125726214',
#    'sodUtc0': '3.244',
#    'sodUtc8': '3.09'},
#   {'instType': 'SPOT',
#    'instId': 'JTO-USDT',
#    'last': '1.449',
#    'lastSz': '0.502',
#    'askPx': '1.451',
#    'askSz': '3829.7003',
#    'bidPx': '1.449',
#    'bidSz': '2676.1015',
#    'open24h': '1.551',
#    'high24h': '1.589',
#    'low24h': '1.431',
#    'volCcy24h': '1038881.6896859',
#    'vol24h': '687516.5614',
#    'ts': '1760125725722',
#    'sodUtc0': '1.562',
#    'sodUtc8': '1.49'},
#   {'instType': 'SPOT',
#    'instId': 'STETH-ETH',
#    'last': '0.9993',
#    'lastSz': '0.359956',
#    'askPx': '0.9997',
#    'askSz': '0.02003',
#    'bidPx': '0.9994',
#    'bidSz': '0.386542',
#    'open24h': '0.9994',
#    'high24h': '0.9999',
#    'low24h': '0.9992',
#    'volCcy24h': '38.2892886395',
#    'vol24h': '38.302004',
#    'ts': '1760125722208',
#    'sodUtc0': '0.9994',
#    'sodUtc8': '0.9997'},
#   {'instType': 'SPOT',
#    'instId': 'LSK-USDT',
#    'last': '0.266',
#    'lastSz': '19.12231517',
#    'askPx': '0.2665',
#    'askSz': '189.44974626',
#    'bidPx': '0.266',
#    'bidSz': '1094.14727111',
#    'open24h': '0.284',
#    'high24h': '0.2871',
#    'low24h': '0.2635',
#    'volCcy24h': '30909.757170085606',
#    'vol24h': '111518.27455509',
#    'ts': '1760125692515',
#    'sodUtc0': '0.2863',
#    'sodUtc8': '0.2718'},
#   {'instType': 'SPOT',
#    'instId': 'XPL-USDT',
#    'last': '0.6492',
#    'lastSz': '38',
#    'askPx': '0.6493',
#    'askSz': '38',
#    'bidPx': '0.6492',
#    'bidSz': '1972.97',
#    'open24h': '0.7411',
#    'high24h': '0.7593',
#    'low24h': '0.6383',
#    'volCcy24h': '78082633.774363',
#    'vol24h': '112408647.39',
#    'ts': '1760125726623',
#    'sodUtc0': '0.7446',
#    'sodUtc8': '0.6491'},
#   {'instType': 'SPOT',
#    'instId': 'AAVE-USD',
#    'last': '259.25',
#    'lastSz': '1.769836',
#    'askPx': '259.39',
#    'askSz': '0.088688',
#    'bidPx': '259.27',
#    'bidSz': '0.083695',
#    'open24h': '272',
#    'high24h': '279.93',
#    'low24h': '255.82',
#    'volCcy24h': '27874.07575234',
#    'vol24h': '103.861088',
#    'ts': '1760125726051',
#    'sodUtc0': '273.84',
#    'sodUtc8': '263.94'},
#   {'instType': 'SPOT',
#    'instId': 'SWFTC-USD',
#    'last': '0.007878',
#    'lastSz': '6335.365724',
#    'askPx': '0.007924',
#    'askSz': '37859.666834',
#    'bidPx': '0.007833',
#    'bidSz': '29667.048998',
#    'open24h': '0.008208',
#    'high24h': '0.008274',
#    'low24h': '0.007867',
#    'volCcy24h': '735.422704820674',
#    'vol24h': '90154.413909',
#    'ts': '1760125726810',
#    'sodUtc0': '0.008274',
#    'sodUtc8': '0.007878'},
#   {'instType': 'SPOT',
#    'instId': 'RSR-USD',
#    'last': '0.005403',
#    'lastSz': '3916.422564',
#    'askPx': '0.005465',
#    'askSz': '12853.929912',
#    'bidPx': '0.005402',
#    'bidSz': '75897.815623',
#    'open24h': '0.006603',
#    'high24h': '0.006603',
#    'low24h': '0.005403',
#    'volCcy24h': '124.667162048889',
#    'vol24h': '21118.804305',
#    'ts': '1760125718134',
#    'sodUtc0': '0.006017',
#    'sodUtc8': '0.005403'},
#   {'instType': 'SPOT',
#    'instId': 'IOTA-USDT',
#    'last': '0.1709',
#    'lastSz': '2475.998692',
#    'askPx': '0.171',
#    'askSz': '16999.004116',
#    'bidPx': '0.1708',
#    'bidSz': '6803.790476',
#    'open24h': '0.1794',
#    'high24h': '0.1839',
#    'low24h': '0.1684',
#    'volCcy24h': '1119900.3468177889',
#    'vol24h': '6340897.490672',
#    'ts': '1760125725314',
#    'sodUtc0': '0.1798',
#    'sodUtc8': '0.173'},
#   {'instType': 'SPOT',
#    'instId': 'OP-USD',
#    'last': '0.6704',
#    'lastSz': '58.1892',
#    'askPx': '0.6705',
#    'askSz': '73.0996',
#    'bidPx': '0.6703',
#    'bidSz': '1119.0433',
#    'open24h': '0.6975',
#    'high24h': '0.7335',
#    'low24h': '0.66',
#    'volCcy24h': '288500.74369432',
#    'vol24h': '406664.5074',
#    'ts': '1760125725313',
#    'sodUtc0': '0.7079',
#    'sodUtc8': '0.6871'},
#   {'instType': 'SPOT',
#    'instId': 'PRCL-USD',
#    'last': '0.06424',
#    'lastSz': '541.506',
#    'askPx': '0.06194',
#    'askSz': '11205.558',
#    'bidPx': '0.0611',
#    'bidSz': '19011.095',
#    'open24h': '0.06775',
#    'high24h': '0.06775',
#    'low24h': '0.06424',
#    'volCcy24h': '34.78634544',
#    'vol24h': '541.506',
#    'ts': '1760125726424',
#    'sodUtc0': '0.06424',
#    'sodUtc8': '0.06424'},
#   {'instType': 'SPOT',
#    'instId': 'ATOM-USD',
#    'last': '3.879',
#    'lastSz': '12.596976',
#    'askPx': '3.938',
#    'askSz': '484.641465',
#    'bidPx': '3.933',
#    'bidSz': '127.136908',
#    'open24h': '4.053',
#    'high24h': '4.161',
#    'low24h': '3.879',
#    'volCcy24h': '29996.495496364',
#    'vol24h': '7441.188728',
#    'ts': '1760125726051',
#    'sodUtc0': '4.062',
#    'sodUtc8': '3.997'},
#   {'instType': 'SPOT',
#    'instId': 'BONK-USDT',
#    'last': '0.000017435',
#    'lastSz': '179824',
#    'askPx': '0.000017438',
#    'askSz': '9451741',
#    'bidPx': '0.000017434',
#    'bidSz': '2641144',
#    'open24h': '0.000018911',
#    'high24h': '0.000019611',
#    'low24h': '0.000017162',
#    'volCcy24h': '6424027.042411718',
#    'vol24h': '352044343748',
#    'ts': '1760125726910',
#    'sodUtc0': '0.000018938',
#    'sodUtc8': '0.000018014'},
#   {'instType': 'SPOT',
#    'instId': 'MENGO-USD',
#    'last': '0.12423',
#    'lastSz': '2012.3963',
#    'askPx': '0.12141',
#    'askSz': '2470.9661',
#    'bidPx': '0.12079',
#    'bidSz': '3394.3207',
#    'open24h': '0.12313',
#    'high24h': '0.12423',
#    'low24h': '0.12313',
#    'volCcy24h': '751.048091734',
#    'vol24h': '6060.7775',
#    'ts': '1760125682511',
#    'sodUtc0': '0.12313',
#    'sodUtc8': '0.12423'},
#   {'instType': 'SPOT',
#    'instId': 'PNUT-USDT',
#    'last': '0.185',
#    'lastSz': '110',
#    'askPx': '0.1853',
#    'askSz': '3000.34',
#    'bidPx': '0.1851',
#    'bidSz': '37106.28',
#    'open24h': '0.2015',
#    'high24h': '0.2086',
#    'low24h': '0.1817',
#    'volCcy24h': '3037034.211732',
#    'vol24h': '15642787.22',
#    'ts': '1760125726714',
#    'sodUtc0': '0.2037',
#    'sodUtc8': '0.1894'},
#   {'instType': 'SPOT',
#    'instId': 'A-USDT',
#    'last': '0.3607',
#    'lastSz': '15',
#    'askPx': '0.3608',
#    'askSz': '15',
#    'bidPx': '0.3606',
#    'bidSz': '454',
#    'open24h': '0.3827',
#    'high24h': '0.392',
#    'low24h': '0.353',
#    'volCcy24h': '1782862.076083',
#    'vol24h': '4748925.64',
#    'ts': '1760125724346',
#    'sodUtc0': '0.3862',
#    'sodUtc8': '0.3666'},
#   {'instType': 'SPOT',
#    'instId': 'XRP-USDC',
#    'last': '2.6885',
#    'lastSz': '1.041',
#    'askPx': '2.6898',
#    'askSz': '1712.315',
#    'bidPx': '2.6892',
#    'bidSz': '2413.749',
#    'open24h': '2.7903',
#    'high24h': '2.8344',
#    'low24h': '2.6545',
#    'volCcy24h': '99637.5339176',
#    'vol24h': '36563.135',
#    'ts': '1760125726220',
#    'sodUtc0': '2.8152',
#    'sodUtc8': '2.7368'},
#   {'instType': 'SPOT',
#    'instId': 'IOST-USD',
#    'last': '0.002892',
#    'lastSz': '2.484',
#    'askPx': '0.002892',
#    'askSz': '103734.439834',
#    'bidPx': '0.002865',
#    'bidSz': '1159592.472927',
#    'open24h': '0.003018',
#    'high24h': '0.003061',
#    'low24h': '0.002892',
#    'volCcy24h': '278.38266499886',
#    'vol24h': '93184.057878',
#    'ts': '1760125716952',
#    'sodUtc0': '0.00303',
#    'sodUtc8': '0.002892'},
#   {'instType': 'SPOT',
#    'instId': 'CSPR-USD',
#    'last': '0.008752',
#    'lastSz': '19740.636299',
#    'askPx': '0.008733',
#    'askSz': '34352.4562',
#    'bidPx': '0.008611',
#    'bidSz': '37691.296516',
#    'open24h': '0.008826',
#    'high24h': '0.009119',
#    'low24h': '0.008752',
#    'volCcy24h': '1180.423765931024',
#    'vol24h': '130631.446928',
#    'ts': '1760125720307',
#    'sodUtc0': '0.009031',
#    'sodUtc8': '0.008752'},
#   {'instType': 'SPOT',
#    'instId': '1INCH-USD',
#    'last': '0.2368',
#    'lastSz': '24.947669',
#    'askPx': '0.2388',
#    'askSz': '1091.696853',
#    'bidPx': '0.2384',
#    'bidSz': '1942.492462',
#    'open24h': '0.244',
#    'high24h': '0.2538',
#    'low24h': '0.2368',
#    'volCcy24h': '3218.3820074457',
#    'vol24h': '12834.287597',
#    'ts': '1760125725419',
#    'sodUtc0': '0.2506',
#    'sodUtc8': '0.2404'},
#   {'instType': 'SPOT',
#    'instId': 'QTUM-USDT',
#    'last': '2.261',
#    'lastSz': '13.063122',
#    'askPx': '2.263',
#    'askSz': '67.893524',
#    'bidPx': '2.261',
#    'bidSz': '354.112909',
#    'open24h': '2.37',
#    'high24h': '2.429',
#    'low24h': '2.227',
#    'volCcy24h': '1524175.631966496',
#    'vol24h': '646318.956609',
#    'ts': '1760125726120',
#    'sodUtc0': '2.418',
#    'sodUtc8': '2.31'},
#   {'instType': 'SPOT',
#    'instId': 'CHZ-EUR',
#    'last': '0.0339',
#    'lastSz': '14.347',
#    'askPx': '0.034',
#    'askSz': '559.62',
#    'bidPx': '0.03392',
#    'bidSz': '211.999',
#    'open24h': '0.03544',
#    'high24h': '0.0364',
#    'low24h': '0.03358',
#    'volCcy24h': '428.81695116',
#    'vol24h': '12184.125',
#    'ts': '1760125725315',
#    'sodUtc0': '0.03559',
#    'sodUtc8': '0.03429'},
#   {'instType': 'SPOT',
#    'instId': 'EIGEN-USDT',
#    'last': '1.6383',
#    'lastSz': '87.494',
#    'askPx': '1.6379',
#    'askSz': '53.051',
#    'bidPx': '1.6373',
#    'bidSz': '94.229',
#    'open24h': '1.7987',
#    'high24h': '1.8305',
#    'low24h': '1.61',
#    'volCcy24h': '3294222.0718052',
#    'vol24h': '1924364.13',
#    'ts': '1760125726409',
#    'sodUtc0': '1.7953',
#    'sodUtc8': '1.6737'},
#   {'instType': 'SPOT',
#    'instId': 'CSPR-USDT',
#    'last': '0.008657',
#    'lastSz': '3744.163999',
#    'askPx': '0.008669',
#    'askSz': '3875.860527',
#    'bidPx': '0.008657',
#    'bidSz': '5366.325406',
#    'open24h': '0.008857',
#    'high24h': '0.009149',
#    'low24h': '0.008513',
#    'volCcy24h': '268651.823079709601',
#    'vol24h': '30176161.524414',
#    'ts': '1760125714050',
#    'sodUtc0': '0.008969',
#    'sodUtc8': '0.008693'},
#   {'instType': 'SPOT',
#    'instId': 'ELON-USDT',
#    'last': '0.00000008538',
#    'lastSz': '881057079',
#    'askPx': '0.0000000856',
#    'askSz': '3214984752',
#    'bidPx': '0.00000008535',
#    'bidSz': '1261856686',
#    'open24h': '0.00000009032',
#    'high24h': '0.00000009261',
#    'low24h': '0.000000085',
#    'volCcy24h': '143179.52739175982',
#    'vol24h': '1615772564117',
#    'ts': '1760125726921',
#    'sodUtc0': '0.00000009064',
#    'sodUtc8': '0.0000000866'},
#   {'instType': 'SPOT',
#    'instId': 'ZKJ-USDT',
#    'last': '0.1193',
#    'lastSz': '2.1015',
#    'askPx': '0.1196',
#    'askSz': '507.6375',
#    'bidPx': '0.1194',
#    'bidSz': '11715.4811',
#    'open24h': '0.1269',
#    'high24h': '0.1309',
#    'low24h': '0.1159',
#    'volCcy24h': '243628.97918039',
#    'vol24h': '1963097.0372',
#    'ts': '1760125721214',
#    'sodUtc0': '0.1281',
#    'sodUtc8': '0.1225'},
#   {'instType': 'SPOT',
#    'instId': 'ZEUS-USD',
#    'last': '0.114',
#    'lastSz': '72.1017',
#    'askPx': '0.1049',
#    'askSz': '2859.8665',
#    'bidPx': '0.1037',
#    'bidSz': '3953.7126',
#    'open24h': '0.114',
#    'high24h': '0.114',
#    'low24h': '0.114',
#    'volCcy24h': '0',
#    'vol24h': '0',
#    'ts': '1760125694909',
#    'sodUtc0': '0.114',
#    'sodUtc8': '0.114'},
#   {'instType': 'SPOT',
#    'instId': 'AXS-USDT',
#    'last': '2.043',
#    'lastSz': '21.21063',
#    'askPx': '2.042',
#    'askSz': '13.05',
#    'bidPx': '2.041',
#    'bidSz': '68.966971',
#    'open24h': '2.176',
#    'high24h': '2.253',
#    'low24h': '2.004',
#    'volCcy24h': '837467.385363717',
#    'vol24h': '386493.014762',
#    'ts': '1760125726018',
#    'sodUtc0': '2.21',
#    'sodUtc8': '2.101'},
#   {'instType': 'SPOT',
#    'instId': 'ASP-USDT',
#    'last': '0.1227',
#    'lastSz': '588.63',
#    'askPx': '0.123',
#    'askSz': '9918.41',
#    'bidPx': '0.1228',
#    'bidSz': '1599.9',
#    'open24h': '0.1241',
#    'high24h': '0.1387',
#    'low24h': '0.1177',
#    'volCcy24h': '5452902.208195',
#    'vol24h': '42837671.06',
#    'ts': '1760125715514',
#    'sodUtc0': '0.1228',
#    'sodUtc8': '0.1218'},
#   {'instType': 'SPOT',
#    'instId': 'MEMEFI-USDT',
#    'last': '0.0011677',
#    'lastSz': '10056.1',
#    'askPx': '0.0011676',
#    'askSz': '100.3',
#    'bidPx': '0.0011639',
#    'bidSz': '487.7',
#    'open24h': '0.0012177',
#    'high24h': '0.0012493',
#    'low24h': '0.0011436',
#    'volCcy24h': '236454.62753671',
#    'vol24h': '196484760.1',
#    'ts': '1760125680524',
#    'sodUtc0': '0.0012186',
#    'sodUtc8': '0.0011939'},
#   {'instType': 'SPOT',
#    'instId': 'S-USD',
#    'last': '0.272',
#    'lastSz': '1',
#    'askPx': '0.2473',
#    'askSz': '286.466',
#    'bidPx': '0.2449',
#    'bidSz': '17590.397',
#    'open24h': '0.2681',
#    'high24h': '0.272',
#    'low24h': '0.2681',
#    'volCcy24h': '0.272',
#    'vol24h': '1',
#    'ts': '1760125707031',
#    'sodUtc0': '0.272',
#    'sodUtc8': '0.272'},
#   {'instType': 'SPOT',
#    'instId': 'LQTY-USDT',
#    'last': '0.6568',
#    'lastSz': '38.5278',
#    'askPx': '0.6573',
#    'askSz': '191.5466',
#    'bidPx': '0.657',
#    'bidSz': '14',
#    'open24h': '0.7221',
#    'high24h': '0.7509',
#    'low24h': '0.6455',
#    'volCcy24h': '659179.48431573',
#    'vol24h': '926254.6652',
#    'ts': '1760125726910',
#    'sodUtc0': '0.7267',
#    'sodUtc8': '0.6865'},
#   {'instType': 'SPOT',
#    'instId': 'BCH-USDC',
#    'last': '562.1',
#    'lastSz': '0.01866',
#    'askPx': '563',
#    'askSz': '0.02233',
#    'bidPx': '562.3',
#    'bidSz': '0.91155',
#    'open24h': '571.3',
#    'high24h': '595.4',
#    'low24h': '562',
#    'volCcy24h': '283.24225',
#    'vol24h': '0.48917',
#    'ts': '1760125726918',
#    'sodUtc0': '586.9',
#    'sodUtc8': '570.2'},
#   {'instType': 'SPOT',
#    'instId': 'PEOPLE-USD',
#    'last': '0.0153',
#    'lastSz': '8757.051454',
#    'askPx': '0.0151',
#    'askSz': '26546.853146',
#    'bidPx': '0.01495',
#    'bidSz': '222294.787221',
#    'open24h': '0.01764',
#    'high24h': '0.01764',
#    'low24h': '0.0153',
#    'volCcy24h': '781.70670715905',
#    'vol24h': '50875.249867',
#    'ts': '1760125725216',
#    'sodUtc0': '0.01545',
#    'sodUtc8': '0.01545'},
#   {'instType': 'SPOT',
#    'instId': 'OMI-USD',
#    'last': '0.0002445',
#    'lastSz': '335238.1',
#    'askPx': '0.0002478',
#    'askSz': '1210653.753',
#    'bidPx': '0.0002428',
#    'bidSz': '948601.887',
#    'open24h': '0.0002753',
#    'high24h': '0.0002753',
#    'low24h': '0.0002445',
#    'volCcy24h': '2081.723102968',
#    'vol24h': '7974659.545',
#    'ts': '1760125726911',
#    'sodUtc0': '0.0002648',
#    'sodUtc8': '0.0002539'},
#   {'instType': 'SPOT',
#    'instId': 'IP-USDC',
#    'last': '9.124',
#    'lastSz': '0',
#    'askPx': '8.194',
#    'askSz': '61.02',
#    'bidPx': '8.175',
#    'bidSz': '137.172',
#    'open24h': '9.124',
#    'high24h': '9.124',
#    'low24h': '9.124',
#    'volCcy24h': '0',
#    'vol24h': '0',
#    'ts': '1760125726509',
#    'sodUtc0': '9.124',
#    'sodUtc8': '9.124'},
#   {'instType': 'SPOT',
#    'instId': 'VELO-USDT',
#    'last': '0.01192',
#    'lastSz': '1071.744938',
#    'askPx': '0.011938',
#    'askSz': '5000',
#    'bidPx': '0.011918',
#    'bidSz': '938.072645',
#    'open24h': '0.011956',
#    'high24h': '0.012315',
#    'low24h': '0.01184',
#    'volCcy24h': '762097.553475283179',
#    'vol24h': '63454788.651828',
#    'ts': '1760125726220',
#    'sodUtc0': '0.012047',
#    'sodUtc8': '0.011959'},
#   {'instType': 'SPOT',
#    'instId': 'ETC-USDT',
#    'last': '18.41',
#    'lastSz': '18.202678',
#    'askPx': '18.42',
#    'askSz': '454.188789',
#    'bidPx': '18.41',
#    'bidSz': '151.275097',
#    'open24h': '18.98',
#    'high24h': '20.6',
#    'low24h': '18.12',
#    'volCcy24h': '14682597.67505382',
#    'vol24h': '748056.922407',
#    'ts': '1760125726706',
#    'sodUtc0': '19.18',
#    'sodUtc8': '18.98'},
#   {'instType': 'SPOT',
#    'instId': 'CTC-USD',
#    'last': '0.5725',
#    'lastSz': '19.962624',
#    'askPx': '0.5223',
#    'askSz': '271.020236',
#    'bidPx': '0.5164',
#    'bidSz': '6423.385007',
#    'open24h': '0.5725',
#    'high24h': '0.5725',
#    'low24h': '0.5725',
#    'volCcy24h': '0',
#    'vol24h': '0',
#    'ts': '1760125725722',
#    'sodUtc0': '0.5725',
#    'sodUtc8': '0.5725'},
#   {'instType': 'SPOT',
#    'instId': 'XLM-USD',
#    'last': '0.35764',
#    'lastSz': '117.4646',
#    'askPx': '0.36169',
#    'askSz': '132.19131',
#    'bidPx': '0.36155',
#    'bidSz': '143.805132',
#    'open24h': '0.37718',
#    'high24h': '0.38574',
#    'low24h': '0.35754',
#    'volCcy24h': '142605.8841938532',
#    'vol24h': '384415.728516',
#    'ts': '1760125725722',
#    'sodUtc0': '0.38026',
#    'sodUtc8': '0.36766'},
#   {'instType': 'SPOT',
#    'instId': 'VELODROME-USD',
#    'last': '0.0438',
#    'lastSz': '1676.6502',
#    'askPx': '0.04187',
#    'askSz': '7165.0346',
#    'bidPx': '0.04146',
#    'bidSz': '9889.0496',
#    'open24h': '0.04543',
#    'high24h': '0.04543',
#    'low24h': '0.0438',
#    'volCcy24h': '85.48476222',
#    'vol24h': '1951.7069',
#    'ts': '1760125716058',
#    'sodUtc0': '0.0438',
#    'sodUtc8': '0.0438'},
#   {'instType': 'SPOT',
#    'instId': 'ACE-USD',
#    'last': '0.4378',
#    'lastSz': '45.1996',
#    'askPx': '0.4431',
#    'askSz': '677.048',
#    'bidPx': '0.4384',
#    'bidSz': '935.2189',
#    'open24h': '0.4651',
#    'high24h': '0.494',
#    'low24h': '0.4378',
#    'volCcy24h': '1298.00386478',
#    'vol24h': '2751.4642',
#    'ts': '1760125723534',
#    'sodUtc0': '0.4891',
#    'sodUtc8': '0.4378'},
#   {'instType': 'SPOT',
#    'instId': 'ASTR-USDT',
#    'last': '0.02347',
#    'lastSz': '3818.087',
#    'askPx': '0.02349',
#    'askSz': '84074.019288',
#    'bidPx': '0.02346',
#    'bidSz': '14091.384836',
#    'open24h': '0.02544',
#    'high24h': '0.0261',
#    'low24h': '0.02312',
#    'volCcy24h': '1442562.24171381875',
#    'vol24h': '58470804.456186',
#    'ts': '1760125726314',
#    'sodUtc0': '0.0255',
#    'sodUtc8': '0.0238'},
#   {'instType': 'SPOT',
#    'instId': 'USDC-AUD',
#    'last': '1.5263',
#    'lastSz': '745.932',
#    'askPx': '1.5437',
#    'askSz': '500',
#    'bidPx': '1.5406',
#    'bidSz': '500',
#    'open24h': '1.5112',
#    'high24h': '1.5266',
#    'low24h': '1.5112',
#    'volCcy24h': '11846.6516571',
#    'vol24h': '7770.579',
#    'ts': '1760125726768',
#    'sodUtc0': '1.5266',
#    'sodUtc8': '1.5263'},
#   {'instType': 'SPOT',
#    'instId': 'IP-USDT',
#    'last': '8.185',
#    'lastSz': '1.5',
#    'askPx': '8.184',
#    'askSz': '34.278',
#    'bidPx': '8.182',
#    'bidSz': '1.5',
#    'open24h': '8.91',
#    'high24h': '8.989',
#    'low24h': '8.095',
#    'volCcy24h': '13657188.207911',
#    'vol24h': '1584529.844',
#    'ts': '1760125726513',
#    'sodUtc0': '8.776',
#    'sodUtc8': '8.47'},
#   {'instType': 'SPOT',
#    'instId': 'VELO-USD',
#    'last': '0.011886',
#    'lastSz': '6073.042385',
#    'askPx': '0.012019',
#    'askSz': '24960.479241',
#    'bidPx': '0.01187',
#    'bidSz': '26209.4071',
#    'open24h': '0.011979',
#    'high24h': '0.01212',
#    'low24h': '0.011886',
#    'volCcy24h': '3588.167493179118',
#    'vol24h': '300536.439636',
#    'ts': '1760125711519',
#    'sodUtc0': '0.01212',
#    'sodUtc8': '0.01192'},
#   {'instType': 'SPOT',
#    'instId': 'BCH-USDT',
#    'last': '562.8',
#    'lastSz': '1.007754',
#    'askPx': '562.7',
#    'askSz': '1.68966',
#    'bidPx': '562.6',
#    'bidSz': '1.013312',
#    'open24h': '575.3',
#    'high24h': '601',
#    'low24h': '556.2',
#    'volCcy24h': '11964624.9881704',
#    'vol24h': '20498.454225',
#    'ts': '1760125726911',
#    'sodUtc0': '580',
#    'sodUtc8': '577.2'},
#   {'instType': 'SPOT',
#    'instId': 'SNX-USD',
#    'last': '1.257',
#    'lastSz': '1.259',
#    'askPx': '1.2757',
#    'askSz': '150.82828',
#    'bidPx': '1.2673',
#    'bidSz': '2952.050021',
#    'open24h': '1.1851',
#    'high24h': '1.4267',
#    'low24h': '1.178',
#    'volCcy24h': '7237.1004261547',
#    'vol24h': '5455.007787',
#    'ts': '1760125714309',
#    'sodUtc0': '1.2867',
#    'sodUtc8': '1.2818'},
#   {'instType': 'SPOT',
#    'instId': 'SAFE-USDT',
#    'last': '0.332',
#    'lastSz': '48.358',
#    'askPx': '0.3319',
#    'askSz': '199.824',
#    'bidPx': '0.3317',
#    'bidSz': '2048.81',
#    'open24h': '0.3561',
#    'high24h': '0.3609',
#    'low24h': '0.3266',
#    'volCcy24h': '738254.4289688',
#    'vol24h': '2111802.206',
#    'ts': '1760125722508',
#    'sodUtc0': '0.3588',
#    'sodUtc8': '0.341'},
#   {'instType': 'SPOT',
#    'instId': 'BOME-USD',
#    'last': '0.001475',
#    'lastSz': '37409',
#    'askPx': '0.00149',
#    'askSz': '22663',
#    'bidPx': '0.001475',
#    'bidSz': '2454551',
#    'open24h': '0.001605',
#    'high24h': '0.001612',
#    'low24h': '0.001475',
#    'volCcy24h': '126.028087',
#    'vol24h': '84486',
#    'ts': '1760125725423',
#    'sodUtc0': '0.001612',
#    'sodUtc8': '0.001475'},
#   {'instType': 'SPOT',
#    'instId': 'XRP-EUR',
#    'last': '2.3175',
#    'lastSz': '13.1477',
#    'askPx': '2.3176',
#    'askSz': '467.8644',
#    'bidPx': '2.3175',
#    'bidSz': '183',
#    'open24h': '2.4102',
#    'high24h': '2.4517',
#    'low24h': '2.2735',
#    'volCcy24h': '808467.11523551',
#    'vol24h': '344180.9102',
#    'ts': '1760125724815',
#    'sodUtc0': '2.4251',
#    'sodUtc8': '2.3594'},
#   {'instType': 'SPOT',
#    'instId': 'WCT-USD',
#    'last': '0.2237',
#    'lastSz': '125.94',
#    'askPx': '0.2254',
#    'askSz': '600',
#    'bidPx': '0.2247',
#    'bidSz': '600',
#    'open24h': '0.2528',
#    'high24h': '0.2548',
#    'low24h': '0.2237',
#    'volCcy24h': '4098.867141',
#    'vol24h': '17137.14',
#    'ts': '1760125718326',
#    'sodUtc0': '0.2493',
#    'sodUtc8': '0.2324'},
#   {'instType': 'SPOT',
#    'instId': 'XRP-TRY',
#    'last': '112.89',
#    'lastSz': '0.33793',
#    'askPx': '112.96',
#    'askSz': '994.89873',
#    'bidPx': '112.83',
#    'bidSz': '100',
#    'open24h': '116.5',
#    'high24h': '118.39',
#    'low24h': '110.94',
#    'volCcy24h': '6020157.3560102',
#    'vol24h': '51965.22075',
#    'ts': '1760125724710',
#    'sodUtc0': '117.43',
#    'sodUtc8': '114.92'},
#   {'instType': 'SPOT',
#    'instId': 'APT-USDT',
#    'last': '4.807',
#    'lastSz': '123.4956',
#    'askPx': '4.807',
#    'askSz': '115.199',
#    'bidPx': '4.805',
#    'bidSz': '171.5044',
#    'open24h': '4.993',
#    'high24h': '5.119',
#    'low24h': '4.744',
#    'volCcy24h': '7458208.695009',
#    'vol24h': '1507996.9935',
#    'ts': '1760125726121',
#    'sodUtc0': '5.008',
#    'sodUtc8': '4.882'},
#   {'instType': 'SPOT',
#    'instId': 'GAS-USDT',
#    'last': '2.841',
#    'lastSz': '24.988048',
#    'askPx': '2.847',
#    'askSz': '24.910676',
#    'bidPx': '2.844',
#    'bidSz': '28.510676',
#    'open24h': '2.976',
#    'high24h': '3.027',
#    'low24h': '2.808',
#    'volCcy24h': '389752.430698352',
#    'vol24h': '131288.125703',
#    'ts': '1760125723865',
#    'sodUtc0': '2.994',
#    'sodUtc8': '2.895'},
#   {'instType': 'SPOT',
#    'instId': 'TRX-USDT',
#    'last': '0.33118',
#    'lastSz': '603.756826',
#    'askPx': '0.3312',
#    'askSz': '884.449039',
#    'bidPx': '0.33118',
#    'bidSz': '603.822704',
#    'open24h': '0.33647',
#    'high24h': '0.33726',
#    'low24h': '0.3276',
#    'volCcy24h': '8621941.28256026783',
#    'vol24h': '25873024.831337',
#    'ts': '1760125726911',
#    'sodUtc0': '0.337',
#    'sodUtc8': '0.33033'},
#   {'instType': 'SPOT',
#    'instId': 'CELR-USDT',
#    'last': '0.00738',
#    'lastSz': '4065.04065',
#    'askPx': '0.007406',
#    'askSz': '604.582485',
#    'bidPx': '0.007367',
#    'bidSz': '22213.160234',
#    'open24h': '0.0084',
#    'high24h': '0.008588',
#    'low24h': '0.007319',
#    'volCcy24h': '375176.613086654879',
#    'vol24h': '45937957.341605',
#    'ts': '1760125726921',
#    'sodUtc0': '0.008134',
#    'sodUtc8': '0.007626'},
#   {'instType': 'SPOT',
#    'instId': 'VRA-USD',
#    'last': '0.001027',
#    'lastSz': '271232.477769',
#    'askPx': '0.001038',
#    'askSz': '289017.34104',
#    'bidPx': '0.001015',
#    'bidSz': '403940.886699',
#    'open24h': '0.001053',
#    'high24h': '0.001056',
#    'low24h': '0.001016',
#    'volCcy24h': '3567.376120909972',
#    'vol24h': '3451621.560941',
#    'ts': '1760125722522',
#    'sodUtc0': '0.001036',
#    'sodUtc8': '0.001028'},
#   {'instType': 'SPOT',
#    'instId': 'CELO-USDT',
#    'last': '0.3328',
#    'lastSz': '70.1095',
#    'askPx': '0.3329',
#    'askSz': '15',
#    'bidPx': '0.3328',
#    'bidSz': '149.406923',
#    'open24h': '0.3647',
#    'high24h': '0.4065',
#    'low24h': '0.3292',
#    'volCcy24h': '5117366.6729211099',
#    'vol24h': '13933163.176663',
#    'ts': '1760125725315',
#    'sodUtc0': '0.3587',
#    'sodUtc8': '0.3385'},
#   {'instType': 'SPOT',
#    'instId': 'XTZ-USD',
#    'last': '0.6622',
#    'lastSz': '0.971167',
#    'askPx': '0.6541',
#    'askSz': '115.638855',
#    'bidPx': '0.6484',
#    'bidSz': '5127.484224',
#    'open24h': '0.669',
#    'high24h': '0.6827',
#    'low24h': '0.6605',
#    'volCcy24h': '489.4123461752',
#    'vol24h': '719.281298',
#    'ts': '1760125725315',
#    'sodUtc0': '0.6823',
#    'sodUtc8': '0.6605'},
#   {'instType': 'SPOT',
#    'instId': 'W-USDT',
#    'last': '0.09839',
#    'lastSz': '508.9761',
#    'askPx': '0.09846',
#    'askSz': '3444.6724',
#    'bidPx': '0.09841',
#    'bidSz': '488.7063',
#    'open24h': '0.11036',
#    'high24h': '0.11363',
#    'low24h': '0.09664',
#    'volCcy24h': '5505904.520002044',
#    'vol24h': '52245020.2969',
#    'ts': '1760125726515',
#    'sodUtc0': '0.11244',
#    'sodUtc8': '0.10168'},
#   {'instType': 'SPOT',
#    'instId': 'SAND-USDT',
#    'last': '0.2518',
#    'lastSz': '87.910599',
#    'askPx': '0.2518',
#    'askSz': '3075.66043',
#    'bidPx': '0.2517',
#    'bidSz': '1039.900316',
#    'open24h': '0.2632',
#    'high24h': '0.2731',
#    'low24h': '0.2481',
#    'volCcy24h': '1206360.4503690054',
#    'vol24h': '4606135.224434',
#    'ts': '1760125726050',
#    'sodUtc0': '0.2657',
#    'sodUtc8': '0.2563'},
#   {'instType': 'SPOT',
#    'instId': 'LAT-USDT',
#    'last': '0.002855',
#    'lastSz': '15645.150792',
#    'askPx': '0.002855',
#    'askSz': '90380.211069',
#    'bidPx': '0.002854',
#    'bidSz': '23821.985408',
#    'open24h': '0.002962',
#    'high24h': '0.003024',
#    'low24h': '0.002855',
#    'volCcy24h': '520293.41345574185',
#    'vol24h': '175297913.332631',
#    'ts': '1760125685126',
#    'sodUtc0': '0.002964',
#    'sodUtc8': '0.002931'},
#   {'instType': 'SPOT',
#    'instId': 'APT-USDC',
#    'last': '5.039',
#    'lastSz': '19.3522',
#    'askPx': '4.808',
#    'askSz': '5.5137',
#    'bidPx': '4.807',
#    'bidSz': '5.5158',
#    'open24h': '5.049',
#    'high24h': '5.049',
#    'low24h': '5.036',
#    'volCcy24h': '597.5154994',
#    'vol24h': '118.6373',
#    'ts': '1760125726910',
#    'sodUtc0': '5.039',
#    'sodUtc8': '5.039'},
#   {'instType': 'SPOT',
#    'instId': 'LDO-EUR',
#    'last': '0.9492',
#    'lastSz': '1.0087',
#    'askPx': '0.9552',
#    'askSz': '90.2299',
#    'bidPx': '0.952',
#    'bidSz': '75.5693',
#    'open24h': '0.9872',
#    'high24h': '1.0378',
#    'low24h': '0.9387',
#    'volCcy24h': '1620.56420536',
#    'vol24h': '1645.1188',
#    'ts': '1760125726515',
#    'sodUtc0': '1.0062',
#    'sodUtc8': '0.9682'},
#   {'instType': 'SPOT',
#    'instId': 'T-USDT',
#    'last': '0.01448',
#    'lastSz': '200',
#    'askPx': '0.01451',
#    'askSz': '243.3748',
#    'bidPx': '0.01449',
#    'bidSz': '689.893',
#    'open24h': '0.01523',
#    'high24h': '0.01552',
#    'low24h': '0.01433',
#    'volCcy24h': '30474.138300064',
#    'vol24h': '2003760.3025',
#    'ts': '1760125725218',
#    'sodUtc0': '0.01543',
#    'sodUtc8': '0.01478'},
#   {'instType': 'SPOT',
#    'instId': 'PUMP-USDT',
#    'last': '0.005259',
#    'lastSz': '47000',
#    'askPx': '0.005259',
#    'askSz': '22259',
#    'bidPx': '0.005258',
#    'bidSz': '215262',
#    'open24h': '0.005412',
#    'high24h': '0.005634',
#    'low24h': '0.004966',
#    'volCcy24h': '31992829.69299',
#    'vol24h': '6017033217',
#    'ts': '1760125726911',
#    'sodUtc0': '0.005533',
#    'sodUtc8': '0.005047'},
#   {'instType': 'SPOT',
#    'instId': 'ANIME-USD',
#    'last': '0.0129',
#    'lastSz': '3447.23',
#    'askPx': '0.01283',
#    'askSz': '7000',
#    'bidPx': '0.01273',
#    'bidSz': '267854.54',
#    'open24h': '0.01357',
#    'high24h': '0.01382',
#    'low24h': '0.0129',
#    'volCcy24h': '190.3802742',
#    'vol24h': '14005.19',
#    'ts': '1760125725916',
#    'sodUtc0': '0.01382',
#    'sodUtc8': '0.0129'},
#   {'instType': 'SPOT',
#    'instId': 'CRO-USDT',
#    'last': '0.1829',
#    'lastSz': '15',
#    'askPx': '0.18275',
#    'askSz': '397.994698',
#    'bidPx': '0.18267',
#    'bidSz': '300.444823',
#    'open24h': '0.19304',
#    'high24h': '0.19414',
#    'low24h': '0.17944',
#    'volCcy24h': '3016436.05813172634',
#    'vol24h': '16092246.30167',
#    'ts': '1760125725424',
#    'sodUtc0': '0.19293',
#    'sodUtc8': '0.18467'},
#   {'instType': 'SPOT',
#    'instId': 'RDNT-USD',
#    'last': '0.02335',
#    'lastSz': '6.5',
#    'askPx': '0.02262',
#    'askSz': '3356.999',
#    'bidPx': '0.02233',
#    'bidSz': '18360.949',
#    'open24h': '0.02315',
#    'high24h': '0.02335',
#    'low24h': '0.02315',
#    'volCcy24h': '15.1775',
#    'vol24h': '650',
#    'ts': '1760125724611',
#    'sodUtc0': '0.02335',
#    'sodUtc8': '0.02335'},
#   {'instType': 'SPOT',
#    'instId': 'RAY-USD',
#    'last': '2.9082',
#    'lastSz': '4.876832',
#    'askPx': '2.4638',
#    'askSz': '53.206068',
#    'bidPx': '2.4401',
#    'bidSz': '168.0259',
#    'open24h': '2.9082',
#    'high24h': '2.9082',
#    'low24h': '2.9082',
#    'volCcy24h': '0',
#    'vol24h': '0',
#    'ts': '1760125726413',
#    'sodUtc0': '2.9082',
#    'sodUtc8': '2.9082'},
#   {'instType': 'SPOT',
#    'instId': 'API3-USD',
#    'last': '0.7542',
#    'lastSz': '0.0063',
#    'askPx': '0.7639',
#    'askSz': '25.471914',
#    'bidPx': '0.7574',
#    'bidSz': '2939.380916',
#    'open24h': '0.8259',
#    'high24h': '0.8812',
#    'low24h': '0.7542',
#    'volCcy24h': '916.4296757477',
#    'vol24h': '1129.807715',
#    'ts': '1760125725515',
#    'sodUtc0': '0.8254',
#    'sodUtc8': '0.7617'},
#   {'instType': 'SPOT',
#    'instId': 'RAY-USDT',
#    'last': '2.4475',
#    'lastSz': '204.271856',
#    'askPx': '2.4499',
#    'askSz': '204.075105',
#    'bidPx': '2.4483',
#    'bidSz': '13.054895',
#    'open24h': '2.6681',
#    'high24h': '2.733',
#    'low24h': '2.4029',
#    'volCcy24h': '1306164.4137563726',
#    'vol24h': '505709.436249',
#    'ts': '1760125726005',
#    'sodUtc0': '2.6917',
#    'sodUtc8': '2.5216'},
#   {'instType': 'SPOT',
#    'instId': 'FLM-USDT',
#    'last': '0.02339',
#    'lastSz': '0.172728',
#    'askPx': '0.02342',
#    'askSz': '13249.553881',
#    'bidPx': '0.02336',
#    'bidSz': '1762.554658',
#    'open24h': '0.02444',
#    'high24h': '0.02547',
#    'low24h': '0.02289',
#    'volCcy24h': '113765.27487848932',
#    'vol24h': '4636830.911547',
#    'ts': '1760125726603',
#    'sodUtc0': '0.02464',
#    'sodUtc8': '0.02397'},
#   {'instType': 'SPOT',
#    'instId': 'JOE-USD',
#    'last': '0.1584',
#    'lastSz': '11.001916',
#    'askPx': '0.1451',
#    'askSz': '1487.156633',
#    'bidPx': '0.1436',
#    'bidSz': '286.435625',
#    'open24h': '0.1584',
#    'high24h': '0.1584',
#    'low24h': '0.1584',
#    'volCcy24h': '0',
#    'vol24h': '0',
#    'ts': '1760125722714',
#    'sodUtc0': '0.1584',
#    'sodUtc8': '0.1584'},
#   {'instType': 'SPOT',
#    'instId': 'PEPE-BRL',
#    'last': '0.00004729',
#    'lastSz': '348592',
#    'askPx': '0.00004756',
#    'askSz': '127276575',
#    'bidPx': '0.00004752',
#    'bidSz': '21048200',
#    'open24h': '0.00004907',
#    'high24h': '0.00005076',
#    'low24h': '0.00004557',
#    'volCcy24h': '371375.77255864',
#    'vol24h': '7794848329',
#    'ts': '1760125726518',
#    'sodUtc0': '0.00004989',
#    'sodUtc8': '0.00004779'},
#   {'instType': 'SPOT',
#    'instId': 'SCR-USD',
#    'last': '0.2491',
#    'lastSz': '129.802',
#    'askPx': '0.2484',
#    'askSz': '949.331',
#    'bidPx': '0.2457',
#    'bidSz': '13516.873',
#    'open24h': '0.2877',
#    'high24h': '0.2877',
#    'low24h': '0.2491',
#    'volCcy24h': '426.3105358',
#    'vol24h': '1706.588',
#    'ts': '1760125721522',
#    'sodUtc0': '0.2703',
#    'sodUtc8': '0.2493'},
#   {'instType': 'SPOT',
#    'instId': 'CRO-EUR',
#    'last': '0.15751',
#    'lastSz': '54.698',
#    'askPx': '0.15757',
#    'askSz': '70.271',
#    'bidPx': '0.15733',
#    'bidSz': '547.814',
#    'open24h': '0.16718',
#    'high24h': '0.16741',
#    'low24h': '0.15519',
#    'volCcy24h': '3615.60227979',
#    'vol24h': '22644.229',
#    'ts': '1760125724815',
#    'sodUtc0': '0.1663',
#    'sodUtc8': '0.15885'},
#   {'instType': 'SPOT',
#    'instId': 'XLM-EUR',
#    'last': '0.312',
#    'lastSz': '55.812',
#    'askPx': '0.31218',
#    'askSz': '276.083',
#    'bidPx': '0.31132',
#    'bidSz': '276.845',
#    'open24h': '0.32649',
#    'high24h': '0.33356',
#    'low24h': '0.30883',
#    'volCcy24h': '5990.388315',
#    'vol24h': '18784.119',
#    'ts': '1760125724012',
#    'sodUtc0': '0.3284',
#    'sodUtc8': '0.31691'},
#   {'instType': 'SPOT',
#    'instId': 'PIXEL-USDT',
#    'last': '0.02491',
#    'lastSz': '33.12',
#    'askPx': '0.02491',
#    'askSz': '395.12',
#    'bidPx': '0.0249',
#    'bidSz': '397.1',
#    'open24h': '0.02646',
#    'high24h': '0.02739',
#    'low24h': '0.0244',
#    'volCcy24h': '299713.6264683',
#    'vol24h': '11505022.49',
#    'ts': '1760125721116',
#    'sodUtc0': '0.02678',
#    'sodUtc8': '0.0253'},
#   {'instType': 'SPOT',
#    'instId': 'SOL-USDT',
#    'last': '206.84',
#    'lastSz': '0.769192',
#    'askPx': '206.86',
#    'askSz': '22.462198',
#    'bidPx': '206.85',
#    'bidSz': '46.39',
#    'open24h': '218.26',
#    'high24h': '224.42',
#    'low24h': '203.39',
#    'volCcy24h': '225038315.22283147',
#    'vol24h': '1046659.69795',
#    'ts': '1760125726910',
#    'sodUtc0': '220.94',
#    'sodUtc8': '210.67'},
#   {'instType': 'SPOT',
#    'instId': 'API3-USDT',
#    'last': '0.7592',
#    'lastSz': '115.9728',
#    'askPx': '0.7589',
#    'askSz': '36.216317',
#    'bidPx': '0.7583',
#    'bidSz': '36.186547',
#    'open24h': '0.8036',
#    'high24h': '0.8868',
#    'low24h': '0.7473',
#    'volCcy24h': '2549629.0393011549',
#    'vol24h': '3110940.811406',
#    'ts': '1760125724130',
#    'sodUtc0': '0.8129',
#    'sodUtc8': '0.766'},
#   {'instType': 'SPOT',
#    'instId': 'SWFTC-USDT',
#    'last': '0.00787',
#    'lastSz': '13053.419569',
#    'askPx': '0.007872',
#    'askSz': '2746.676105',
#    'bidPx': '0.00786',
#    'bidSz': '2520',
#    'open24h': '0.008327',
#    'high24h': '0.00837',
#    'low24h': '0.0078',
#    'volCcy24h': '117801.469311969897',
#    'vol24h': '14627145.279065',
#    'ts': '1760125726220',
#    'sodUtc0': '0.008251',
#    'sodUtc8': '0.007901'},
#   {'instType': 'SPOT',
#    'instId': 'YFI-USDT',
#    'last': '5102',
#    'lastSz': '0.036',
#    'askPx': '5109',
#    'askSz': '0.026586',
#    'bidPx': '5105',
#    'bidSz': '0.02',
#    'open24h': '5294',
#    'high24h': '5399',
#    'low24h': '5039',
#    'volCcy24h': '491892.362803',
#    'vol24h': '93.877121',
#    'ts': '1760125722622',
#    'sodUtc0': '5299',
#    'sodUtc8': '5152'},
#   {'instType': 'SPOT',
#    'instId': 'USD1-USDT',
#    'last': '0.9989',
#    'lastSz': '81.2037',
#    'askPx': '0.9991',
#    'askSz': '1239.9062',
#    'bidPx': '0.999',
#    'bidSz': '1001.001',
#    'open24h': '0.9993',
#    'high24h': '0.9994',
#    'low24h': '0.9989',
#    'volCcy24h': '21885.56649446',
#    'vol24h': '21903.492',
#    'ts': '1760125706817',
#    'sodUtc0': '0.9993',
#    'sodUtc8': '0.9992'},
#   {'instType': 'SPOT',
#    'instId': 'WCT-USDT',
#    'last': '0.2249',
#    'lastSz': '1200',
#    'askPx': '0.2249',
#    'askSz': '1298.62',
#    'bidPx': '0.2248',
#    'bidSz': '3210.36',
#    'open24h': '0.2525',
#    'high24h': '0.255',
#    'low24h': '0.2215',
#    'volCcy24h': '3054880.889712',
#    'vol24h': '12622695.19',
#    'ts': '1760125725314',
#    'sodUtc0': '0.2509',
#    'sodUtc8': '0.2332'},
#   {'instType': 'SPOT',
#    'instId': 'SATS-USD',
#    'last': '0.00000003448',
#    'lastSz': '21256833',
#    'askPx': '0.00000003462',
#    'askSz': '5169875920',
#    'bidPx': '0.00000003438',
#    'bidSz': '99745909047',
#    'open24h': '0.00000003665',
#    'high24h': '0.00000003753',
#    'low24h': '0.0000000338',
#    'volCcy24h': '10623.71397890492',
#    'vol24h': '306562586806',
#    'ts': '1760125725217',
#    'sodUtc0': '0.00000003724',
#    'sodUtc8': '0.00000003529'},
#   {'instType': 'SPOT',
#    'instId': 'LDO-USDT',
#    'last': '1.106',
#    'lastSz': '62',
#    'askPx': '1.1061',
#    'askSz': '657.2985',
#    'bidPx': '1.1057',
#    'bidSz': '1.5',
#    'open24h': '1.1421',
#    'high24h': '1.2025',
#    'low24h': '1.0852',
#    'volCcy24h': '3985317.35200716',
#    'vol24h': '3455185.9404',
#    'ts': '1760125726510',
#    'sodUtc0': '1.1622',
#    'sodUtc8': '1.1237'},
#   {'instType': 'SPOT',
#    'instId': 'RSS3-USD',
#    'last': '0.03991',
#    'lastSz': '1182.431152',
#    'askPx': '0.03757',
#    'askSz': '7985.09449',
#    'bidPx': '0.03689',
#    'bidSz': '5258.410603',
#    'open24h': '0.03756',
#    'high24h': '0.03991',
#    'low24h': '0.03707',
#    'volCcy24h': '996.54136437843',
#    'vol24h': '25761.550052',
#    'ts': '1760125725722',
#    'sodUtc0': '0.03957',
#    'sodUtc8': '0.03991'},
#   {'instType': 'SPOT',
#    'instId': 'TRA-USDT',
#    'last': '0.3533',
#    'lastSz': '5.605197',
#    'askPx': '0.3534',
#    'askSz': '290.351',
#    'bidPx': '0.353',
#    'bidSz': '8.468296',
#    'open24h': '0.3553',
#    'high24h': '0.3646',
#    'low24h': '0.3533',
#    'volCcy24h': '15510.264583585',
#    'vol24h': '43053.438372',
#    'ts': '1760125716059',
#    'sodUtc0': '0.3624',
#    'sodUtc8': '0.3562'},
#   {'instType': 'SPOT',
#    'instId': 'PHA-USD',
#    'last': '0.10183',
#    'lastSz': '1338.221947',
#    'askPx': '0.09351',
#    'askSz': '3208.213025',
#    'bidPx': '0.09263',
#    'bidSz': '4426.21181',
#    'open24h': '0.10183',
#    'high24h': '0.10183',
#    'low24h': '0.10183',
#    'volCcy24h': '0',
#    'vol24h': '0',
#    'ts': '1760125699432',
#    'sodUtc0': '0.10183',
#    'sodUtc8': '0.10183'},
#   {'instType': 'SPOT',
#    'instId': 'DEGEN-USDT',
#    'last': '0.002471',
#    'lastSz': '123166',
#    'askPx': '0.002473',
#    'askSz': '40000',
#    'bidPx': '0.002469',
#    'bidSz': '108831',
#    'open24h': '0.002718',
#    'high24h': '0.002816',
#    'low24h': '0.002427',
#    'volCcy24h': '355919.992197',
#    'vol24h': '134599528',
#    'ts': '1760125726816',
#    'sodUtc0': '0.002725',
#    'sodUtc8': '0.002606'},
#   {'instType': 'SPOT',
#    'instId': 'MERL-USDT',
#    'last': '0.37083',
#    'lastSz': '49.3',
#    'askPx': '0.37113',
#    'askSz': '35.73',
#    'bidPx': '0.3709',
#    'bidSz': '285.764',
#    'open24h': '0.34237',
#    'high24h': '0.3745',
#    'low24h': '0.33852',
#    'volCcy24h': '3225070.57876383',
#    'vol24h': '9222425.221',
#    'ts': '1760125726509',
#    'sodUtc0': '0.34001',
#    'sodUtc8': '0.3452'},
#   {'instType': 'SPOT',
#    'instId': 'DUCK-USD',
#    'last': '0.002056',
#    'lastSz': '96428.9',
#    'askPx': '0.00209',
#    'askSz': '265601.1',
#    'bidPx': '0.002062',
#    'bidSz': '198836',
#    'open24h': '0.002208',
#    'high24h': '0.002213',
#    'low24h': '0.00203',
#    'volCcy24h': '2508.0669783',
#    'vol24h': '1161502.7',
#    'ts': '1760125714814',
#    'sodUtc0': '0.002213',
#    'sodUtc8': '0.00215'},
#   {'instType': 'SPOT',
#    'instId': 'LINK-EUR',
#    'last': '17.849',
#    'lastSz': '0.491809',
#    'askPx': '17.899',
#    'askSz': '4.815222',
#    'bidPx': '17.844',
#    'bidSz': '4.830064',
#    'open24h': '18.802',
#    'high24h': '19.684',
#    'low24h': '17.805',
#    'volCcy24h': '41594.17838908',
#    'vol24h': '2214.141689',
#    'ts': '1760125725521',
#    'sodUtc0': '19.125',
#    'sodUtc8': '18.416'},
#   {'instType': 'SPOT',
#    'instId': 'FET-USDT',
#    'last': '0.4678',
#    'lastSz': '51.502',
#    'askPx': '0.4679',
#    'askSz': '1.501',
#    'bidPx': '0.4678',
#    'bidSz': '1112.088',
#    'open24h': '0.4974',
#    'high24h': '0.5021',
#    'low24h': '0.4611',
#    'volCcy24h': '4415800.1548319',
#    'vol24h': '9103393.769',
#    'ts': '1760125726220',
#    'sodUtc0': '0.4912',
#    'sodUtc8': '0.4747'},
#   {'instType': 'SPOT',
#    'instId': 'LDO-USD',
#    'last': '1.1049',
#    'lastSz': '1.1029',
#    'askPx': '1.1086',
#    'askSz': '483.5192',
#    'bidPx': '1.1035',
#    'bidSz': '371.545',
#    'open24h': '1.1461',
#    'high24h': '1.1985',
#    'low24h': '1.087',
#    'volCcy24h': '1496.46028678',
#    'vol24h': '1320.4425',
#    'ts': '1760125726911',
#    'sodUtc0': '1.1649',
#    'sodUtc8': '1.123'},
#   {'instType': 'SPOT',
#    'instId': 'NMR-USDT',
#    'last': '14.82',
#    'lastSz': '0.1',
#    'askPx': '14.867',
#    'askSz': '1.767624',
#    'bidPx': '14.854',
#    'bidSz': '1.789322',
#    'open24h': '15.822',
#    'high24h': '16.251',
#    'low24h': '14.56',
#    'volCcy24h': '594164.752809435',
#    'vol24h': '38624.38741',
#    'ts': '1760125725218',
#    'sodUtc0': '15.863',
# ...
#    'askSz': '2762.953774',
#    'bidPx': '0.5413',
#    'bidSz': '2771.370476',
#    'open24h': '0.551',
#    'high24h': '0.5821',
#    'low24h': '0.5481',
#    'volCcy24h': '3082.8760879284',
#    'vol24h': '5439.12781',
#    'ts': '1760125723941',
#    'sodUtc0': '0.5681',
#    'sodUtc8': '0.5513'},
#   {'instType': 'SPOT',
#    'instId': 'ARKM-USD',
#    'last': '0.5094',
#    'lastSz': '47.589',
#    'askPx': '0.4892',
#    'askSz': '793.71',
#    'bidPx': '0.4844',
#    'bidSz': '6862.689',
#    'open24h': '0.5106',
#    'high24h': '0.5106',
#    'low24h': '0.4948',
#    'volCcy24h': '227.7651802',
#    'vol24h': '448.021',
#    'ts': '1760125722322',
#    'sodUtc0': '0.4948',
#    'sodUtc8': '0.5094'},
#   {'instType': 'SPOT',
#    'instId': 'ONE-USDT',
#    'last': '0.008782',
#    'lastSz': '534.500667',
#    'askPx': '0.008793',
#    'askSz': '1490.588971',
#    'bidPx': '0.008775',
#    'bidSz': '3753.262229',
#    'open24h': '0.009236',
#    'high24h': '0.009479',
#    'low24h': '0.008647',
#    'volCcy24h': '98576.769508542759',
#    'vol24h': '10825583.893891',
#    'ts': '1760125726916',
#    'sodUtc0': '0.009229',
#    'sodUtc8': '0.00898'},
#   {'instType': 'SPOT',
#    'instId': 'OM-USD',
#    'last': '0.1481',
#    'lastSz': '0.032032',
#    'askPx': '0.1499',
#    'askSz': '131',
#    'bidPx': '0.1493',
#    'bidSz': '192.602375',
#    'open24h': '0.1581',
#    'high24h': '0.1659',
#    'low24h': '0.1481',
#    'volCcy24h': '2701.3767663361',
#    'vol24h': '17003.324485',
#    'ts': '1760125719542',
#    'sodUtc0': '0.1659',
#    'sodUtc8': '0.156'},
#   {'instType': 'SPOT',
#    'instId': 'ATH-USD',
#    'last': '0.05591',
#    'lastSz': '3563.3',
#    'askPx': '0.05601',
#    'askSz': '3629.9',
#    'bidPx': '0.0559',
#    'bidSz': '1000',
#    'open24h': '0.05389',
#    'high24h': '0.0583',
#    'low24h': '0.05123',
#    'volCcy24h': '135534.058619',
#    'vol24h': '2420022.3',
#    'ts': '1760125726317',
#    'sodUtc0': '0.0535',
#    'sodUtc8': '0.05352'},
#   {'instType': 'SPOT',
#    'instId': 'RENDER-USDT',
#    'last': '3.04',
#    'lastSz': '4.035',
#    'askPx': '3.041',
#    'askSz': '12.788',
#    'bidPx': '3.04',
#    'bidSz': '445.568',
#    'open24h': '3.246',
#    'high24h': '3.338',
#    'low24h': '2.973',
#    'volCcy24h': '2812053.71222',
#    'vol24h': '889366.977',
#    'ts': '1760125726509',
#    'sodUtc0': '3.239',
#    'sodUtc8': '3.099'},
#   {'instType': 'SPOT',
#    'instId': 'AVAX-USDC',
#    'last': '26.119',
#    'lastSz': '0.2608',
#    'askPx': '26.553',
#    'askSz': '18.8302',
#    'bidPx': '26.521',
#    'bidSz': '18.8529',
#    'open24h': '28.37',
#    'high24h': '28.37',
#    'low24h': '26.119',
#    'volCcy24h': '6.8118352',
#    'vol24h': '0.2608',
#    'ts': '1760125725015',
#    'sodUtc0': '26.119',
#    'sodUtc8': '26.119'},
#   {'instType': 'SPOT',
#    'instId': 'LAYER-USDT',
#    'last': '0.3625',
#    'lastSz': '3.041',
#    'askPx': '0.3635',
#    'askSz': '687.764',
#    'bidPx': '0.3632',
#    'bidSz': '112.502',
#    'open24h': '0.3896',
#    'high24h': '0.3965',
#    'low24h': '0.3572',
#    'volCcy24h': '568723.6963408',
#    'vol24h': '1490618.588',
#    'ts': '1760125725717',
#    'sodUtc0': '0.3932',
#    'sodUtc8': '0.3715'},
#   {'instType': 'SPOT',
#    'instId': 'NC-USDT',
#    'last': '0.01504',
#    'lastSz': '233.84',
#    'askPx': '0.01505',
#    'askSz': '1935.72',
#    'bidPx': '0.01504',
#    'bidSz': '953.82',
#    'open24h': '0.01604',
#    'high24h': '0.01608',
#    'low24h': '0.01495',
#    'volCcy24h': '194241.2216231',
#    'vol24h': '12351936.18',
#    'ts': '1760125689111',
#    'sodUtc0': '0.01591',
#    'sodUtc8': '0.01533'},
#   {'instType': 'SPOT',
#    'instId': 'SPURS-USDT',
#    'last': '0.3589',
#    'lastSz': '3.9223',
#    'askPx': '0.3615',
#    'askSz': '66.5837',
#    'bidPx': '0.3611',
#    'bidSz': '8',
#    'open24h': '0.374',
#    'high24h': '0.3865',
#    'low24h': '0.3571',
#    'volCcy24h': '63995.7362237',
#    'vol24h': '170446.1711',
#    'ts': '1760125721914',
#    'sodUtc0': '0.3757',
#    'sodUtc8': '0.3716'},
#   {'instType': 'SPOT',
#    'instId': 'FLOW-USD',
#    'last': '0.347',
#    'lastSz': '15.9',
#    'askPx': '0.3389',
#    'askSz': '417.916143',
#    'bidPx': '0.3362',
#    'bidSz': '9903.400936',
#    'open24h': '0.3572',
#    'high24h': '0.3677',
#    'low24h': '0.3435',
#    'volCcy24h': '465.1801865878',
#    'vol24h': '1291.935424',
#    'ts': '1760125716510',
#    'sodUtc0': '0.3601',
#    'sodUtc8': '0.3435'},
#   {'instType': 'SPOT',
#    'instId': 'FLOKI-USDT',
#    'last': '0.00008702',
#    'lastSz': '39789',
#    'askPx': '0.00008703',
#    'askSz': '569993',
#    'bidPx': '0.00008702',
#    'bidSz': '15000',
#    'open24h': '0.00009237',
#    'high24h': '0.00009568',
#    'low24h': '0.00008547',
#    'volCcy24h': '1287437.66101502',
#    'vol24h': '14113161278',
#    'ts': '1760125725813',
#    'sodUtc0': '0.0000931',
#    'sodUtc8': '0.00008851'},
#   {'instType': 'SPOT',
#    'instId': 'GALFT-USDT',
#    'last': '1.299',
#    'lastSz': '6.565',
#    'askPx': '1.305',
#    'askSz': '102.0685',
#    'bidPx': '1.3',
#    'bidSz': '98.51',
#    'open24h': '1.322',
#    'high24h': '1.329',
#    'low24h': '1.298',
#    'volCcy24h': '16588.2091074',
#    'vol24h': '12649.1301',
#    'ts': '1760125723513',
#    'sodUtc0': '1.323',
#    'sodUtc8': '1.305'},
#   {'instType': 'SPOT',
#    'instId': 'EGLD-EUR',
#    'last': '10.88',
#    'lastSz': '3.00704',
#    'askPx': '10.98',
#    'askSz': '2.6723',
#    'bidPx': '10.93',
#    'bidSz': '1.82133',
#    'open24h': '11.06',
#    'high24h': '11.77',
#    'low24h': '10.88',
#    'volCcy24h': '659.8905403',
#    'vol24h': '59.77397',
#    'ts': '1760125726118',
#    'sodUtc0': '11.57',
#    'sodUtc8': '11.05'},
#   {'instType': 'SPOT',
#    'instId': 'GALA-USDT',
#    'last': '0.01456',
#    'lastSz': '1640.902315',
#    'askPx': '0.01455',
#    'askSz': '48420.406067',
#    'bidPx': '0.01454',
#    'bidSz': '191686.984325',
#    'open24h': '0.01525',
#    'high24h': '0.01599',
#    'low24h': '0.0142',
#    'volCcy24h': '2040612.582542415',
#    'vol24h': '134105875.121787',
#    'ts': '1760125725409',
#    'sodUtc0': '0.01542',
#    'sodUtc8': '0.01482'},
#   {'instType': 'SPOT',
#    'instId': 'LAT-USD',
#    'last': '0.002875',
#    'lastSz': '4184.304151',
#    'askPx': '0.002867',
#    'askSz': '191838.158353',
#    'bidPx': '0.00285',
#    'bidSz': '5338.566464',
#    'open24h': '0.002983',
#    'high24h': '0.003012',
#    'low24h': '0.002875',
#    'volCcy24h': '176.229670126077',
#    'vol24h': '59623.000561',
#    'ts': '1760125680019',
#    'sodUtc0': '0.003012',
#    'sodUtc8': '0.002875'},
#   {'instType': 'SPOT',
#    'instId': 'LTC-EUR',
#    'last': '109.96',
#    'lastSz': '0.080667',
#    'askPx': '109.94',
#    'askSz': '3.919304',
#    'bidPx': '109.93',
#    'bidSz': '2.432835',
#    'open24h': '102.59',
#    'high24h': '117.34',
#    'low24h': '102.59',
#    'volCcy24h': '781161.16087995',
#    'vol24h': '7106.404017',
#    'ts': '1760125726916',
#    'sodUtc0': '109.09',
#    'sodUtc8': '109.53'},
#   {'instType': 'SPOT',
#    'instId': 'LQTY-USD',
#    'last': '0.659',
#    'lastSz': '156.1959',
#    'askPx': '0.6606',
#    'askSz': '116.705',
#    'bidPx': '0.6537',
#    'bidSz': '3100.3697',
#    'open24h': '0.7136',
#    'high24h': '0.7379',
#    'low24h': '0.659',
#    'volCcy24h': '442.97227976',
#    'vol24h': '657.682',
#    'ts': '1760125725419',
#    'sodUtc0': '0.7379',
#    'sodUtc8': '0.6712'},
#   {'instType': 'SPOT',
#    'instId': 'JUP-USD',
#    'last': '0.4027',
#    'lastSz': '30.923',
#    'askPx': '0.4069',
#    'askSz': '2091.199',
#    'bidPx': '0.4039',
#    'bidSz': '1015.102',
#    'open24h': '0.4199',
#    'high24h': '0.4413',
#    'low24h': '0.4027',
#    'volCcy24h': '1804.9836183',
#    'vol24h': '4230.481',
#    'ts': '1760125724914',
#    'sodUtc0': '0.4358',
#    'sodUtc8': '0.4129'},
#   {'instType': 'SPOT',
#    'instId': 'SKL-USD',
#    'last': '0.02178',
#    'lastSz': '1836.547291',
#    'askPx': '0.02213',
#    'askSz': '13556.258472',
#    'bidPx': '0.02191',
#    'bidSz': '18712.916476',
#    'open24h': '0.0244',
#    'high24h': '0.0244',
#    'low24h': '0.02178',
#    'volCcy24h': '1246.1017979723',
#    'vol24h': '53708.871612',
#    'ts': '1760125721106',
#    'sodUtc0': '0.02328',
#    'sodUtc8': '0.02178'},
#   {'instType': 'SPOT',
#    'instId': 'AVAX-USDT',
#    'last': '26.522',
#    'lastSz': '4.85',
#    'askPx': '26.539',
#    'askSz': '6.55105',
#    'bidPx': '26.537',
#    'bidSz': '15.65194',
#    'open24h': '28.06',
#    'high24h': '28.622',
#    'low24h': '26.059',
#    'volCcy24h': '22663062.950680745',
#    'vol24h': '824113.832278',
#    'ts': '1760125726820',
#    'sodUtc0': '28.386',
#    'sodUtc8': '27.003'},
#   {'instType': 'SPOT',
#    'instId': 'MASK-USDT',
#    'last': '1.179',
#    'lastSz': '80.0134',
#    'askPx': '1.179',
#    'askSz': '85.854476',
#    'bidPx': '1.178',
#    'bidSz': '1439.154624',
#    'open24h': '1.242',
#    'high24h': '1.257',
#    'low24h': '1.157',
#    'volCcy24h': '613841.144298652',
#    'vol24h': '506539.74471',
#    'ts': '1760125725217',
#    'sodUtc0': '1.244',
#    'sodUtc8': '1.191'},
#   {'instType': 'SPOT',
#    'instId': 'CITY-USD',
#    'last': '0.9828',
#    'lastSz': '41.3959',
#    'askPx': '0.9393',
#    'askSz': '319.3867',
#    'bidPx': '0.9291',
#    'bidSz': '441.2872',
#    'open24h': '0.9828',
#    'high24h': '0.9828',
#    'low24h': '0.9828',
#    'volCcy24h': '0',
#    'vol24h': '0',
#    'ts': '1760125727016',
#    'sodUtc0': '0.9828',
#    'sodUtc8': '0.9828'},
#   {'instType': 'SPOT',
#    'instId': 'ETHW-USD',
#    'last': '1.282',
#    'lastSz': '19.4961',
#    'askPx': '1.311',
#    'askSz': '18.2586',
#    'bidPx': '1.3',
#    'bidSz': '272',
#    'open24h': '1.364',
#    'high24h': '1.407',
#    'low24h': '1.282',
#    'volCcy24h': '10080.9701862',
#    'vol24h': '7386.3479',
#    'ts': '1760125726513',
#    'sodUtc0': '1.379',
#    'sodUtc8': '1.333'},
#   {'instType': 'SPOT',
#    'instId': 'CFG-USD',
#    'last': '0.2615',
#    'lastSz': '62.861751',
#    'askPx': '0.2645',
#    'askSz': '1134.2155',
#    'bidPx': '0.2611',
#    'bidSz': '1148.037747',
#    'open24h': '0.2811',
#    'high24h': '0.2811',
#    'low24h': '0.2615',
#    'volCcy24h': '132.0235308375',
#    'vol24h': '488.589865',
#    'ts': '1760125723514',
#    'sodUtc0': '0.2715',
#    'sodUtc8': '0.2615'},
#   {'instType': 'SPOT',
#    'instId': 'IOTA-USD',
#    'last': '0.172',
#    'lastSz': '118.785066',
#    'askPx': '0.172',
#    'askSz': '1744.186046',
#    'bidPx': '0.1702',
#    'bidSz': '19541.879273',
#    'open24h': '0.1789',
#    'high24h': '0.1789',
#    'low24h': '0.1709',
#    'volCcy24h': '399.6437885725',
#    'vol24h': '2313.79394',
#    'ts': '1760125724922',
#    'sodUtc0': '0.1709',
#    'sodUtc8': '0.1738'},
#   {'instType': 'SPOT',
#    'instId': 'USDT-USD',
#    'last': '1.0003',
#    'lastSz': '197.5758',
#    'askPx': '1.0003',
#    'askSz': '301846.1687',
#    'bidPx': '1.0002',
#    'bidSz': '34359.4396',
#    'open24h': '1.0006',
#    'high24h': '1.0008',
#    'low24h': '1.0002',
#    'volCcy24h': '23837061.58416441',
#    'vol24h': '23826799.9372',
#    'ts': '1760125709711',
#    'sodUtc0': '1.0006',
#    'sodUtc8': '1.0005'},
#   {'instType': 'SPOT',
#    'instId': 'TOSHI-USDT',
#    'last': '0.0008514',
#    'lastSz': '105130',
#    'askPx': '0.0008506',
#    'askSz': '129874',
#    'bidPx': '0.0008499',
#    'bidSz': '129942',
#    'open24h': '0.0009768',
#    'high24h': '0.0010188',
#    'low24h': '0.0008344',
#    'volCcy24h': '6188857.4677819',
#    'vol24h': '6609387410',
#    'ts': '1760125726118',
#    'sodUtc0': '0.0009687',
#    'sodUtc8': '0.0008866'},
#   {'instType': 'SPOT',
#    'instId': 'BABY-USD',
#    'last': '0.04278',
#    'lastSz': '898.7',
#    'askPx': '0.04335',
#    'askSz': '461.4',
#    'bidPx': '0.04308',
#    'bidSz': '85612.9',
#    'open24h': '0.04652',
#    'high24h': '0.04794',
#    'low24h': '0.04248',
#    'volCcy24h': '1054.275347',
#    'vol24h': '23007.3',
#    'ts': '1760125710522',
#    'sodUtc0': '0.04746',
#    'sodUtc8': '0.04467'},
#   {'instType': 'SPOT',
#    'instId': 'NAVX-USD',
#    'last': '0.04927',
#    'lastSz': '327.97',
#    'askPx': '0.04869',
#    'askSz': '5134.52',
#    'bidPx': '0.04785',
#    'bidSz': '3309.26',
#    'open24h': '0.05181',
#    'high24h': '0.05304',
#    'low24h': '0.04927',
#    'volCcy24h': '55.0314033',
#    'vol24h': '1074.52',
#    'ts': '1760125720881',
#    'sodUtc0': '0.05286',
#    'sodUtc8': '0.04927'},
#   {'instType': 'SPOT',
#    'instId': 'METIS-USD',
#    'last': '11.93',
#    'lastSz': '0.0004',
#    'askPx': '12.12',
#    'askSz': '114.874034',
#    'bidPx': '12',
#    'bidSz': '277.187167',
#    'open24h': '13.09',
#    'high24h': '13.23',
#    'low24h': '11.93',
#    'volCcy24h': '560.84757229',
#    'vol24h': '43.955233',
#    'ts': '1760125717933',
#    'sodUtc0': '12.96',
#    'sodUtc8': '12.44'},
#   {'instType': 'SPOT',
#    'instId': 'BICO-USD',
#    'last': '0.09327',
#    'lastSz': '54.71574',
#    'askPx': '0.08672',
#    'askSz': '1448.091565',
#    'bidPx': '0.08571',
#    'bidSz': '17279.052185',
#    'open24h': '0.09327',
#    'high24h': '0.09327',
#    'low24h': '0.09327',
#    'volCcy24h': '0',
#    'vol24h': '0',
#    'ts': '1760125722429',
#    'sodUtc0': '0.09327',
#    'sodUtc8': '0.09327'},
#   {'instType': 'SPOT',
#    'instId': 'USDC-BRL',
#    'last': '5.505',
#    'lastSz': '228.28093',
#    'askPx': '5.506',
#    'askSz': '86.35872',
#    'bidPx': '5.504',
#    'bidSz': '60',
#    'open24h': '5.381',
#    'high24h': '5.508',
#    'low24h': '5.361',
#    'volCcy24h': '1263383.1821183',
#    'vol24h': '231936.78205',
#    'ts': '1760125725226',
#    'sodUtc0': '5.378',
#    'sodUtc8': '5.486'},
#   {'instType': 'SPOT',
#    'instId': 'ZRX-USD',
#    'last': '0.2394',
#    'lastSz': '119.178639',
#    'askPx': '0.238',
#    'askSz': '1260.504201',
#    'bidPx': '0.2358',
#    'bidSz': '14102.406102',
#    'open24h': '0.2518',
#    'high24h': '0.2518',
#    'low24h': '0.2394',
#    'volCcy24h': '28.5313661766',
#    'vol24h': '119.178639',
#    'ts': '1760125716313',
#    'sodUtc0': '0.2394',
#    'sodUtc8': '0.2394'},
#   {'instType': 'SPOT',
#    'instId': 'USDG-USDT',
#    'last': '0.9997',
#    'lastSz': '11.0033',
#    'askPx': '0.9997',
#    'askSz': '1676.7331',
#    'bidPx': '0.9996',
#    'bidSz': '50',
#    'open24h': '0.9994',
#    'high24h': '0.9998',
#    'low24h': '0.9992',
#    'volCcy24h': '148636.18543375',
#    'vol24h': '148711.0684',
#    'ts': '1760125689809',
#    'sodUtc0': '0.9993',
#    'sodUtc8': '0.9995'},
#   {'instType': 'SPOT',
#    'instId': 'SPK-USD',
#    'last': '0.04605',
#    'lastSz': '429.6',
#    'askPx': '0.04672',
#    'askSz': '3119.4',
#    'bidPx': '0.04652',
#    'bidSz': '1009.7',
#    'open24h': '0.04624',
#    'high24h': '0.05034',
#    'low24h': '0.04605',
#    'volCcy24h': '2495.128302',
#    'vol24h': '50559',
#    'ts': '1760125709862',
#    'sodUtc0': '0.04804',
#    'sodUtc8': '0.04779'},
#   {'instType': 'SPOT',
#    'instId': 'OKSOL-SOL',
#    'last': '0.9998',
#    'lastSz': '0.007137',
#    'askPx': '0.9999',
#    'askSz': '3276.942678',
#    'bidPx': '0.9998',
#    'bidSz': '14455.119725',
#    'open24h': '0.9998',
#    'high24h': '0.9999',
#    'low24h': '0.9998',
#    'volCcy24h': '12299.7454300361',
#    'vol24h': '12301.915327',
#    'ts': '1760125686038',
#    'sodUtc0': '0.9998',
#    'sodUtc8': '0.9999'},
#   {'instType': 'SPOT',
#    'instId': 'GLM-USD',
#    'last': '0.208',
#    'lastSz': '18.1531',
#    'askPx': '0.2077',
#    'askSz': '1444.390948',
#    'bidPx': '0.2054',
#    'bidSz': '16182.885739',
#    'open24h': '0.2162',
#    'high24h': '0.2183',
#    'low24h': '0.208',
#    'volCcy24h': '15.1640196552',
#    'vol24h': '70.320644',
#    'ts': '1760125726018',
#    'sodUtc0': '0.208',
#    'sodUtc8': '0.208'},
#   {'instType': 'SPOT',
#    'instId': 'ZRO-USD',
#    'last': '2.159',
#    'lastSz': '106.36',
#    'askPx': '2.162',
#    'askSz': '115.698',
#    'bidPx': '2.159',
#    'bidSz': '577.585',
#    'open24h': '2.286',
#    'high24h': '2.309',
#    'low24h': '2.132',
#    'volCcy24h': '29903.151203',
#    'vol24h': '13541.3',
#    'ts': '1760125726224',
#    'sodUtc0': '2.273',
#    'sodUtc8': '2.159'},
#   {'instType': 'SPOT',
#    'instId': 'STX-USDT',
#    'last': '0.5467',
#    'lastSz': '1',
#    'askPx': '0.5468',
#    'askSz': '50.48568',
#    'bidPx': '0.5467',
#    'bidSz': '115.667065',
#    'open24h': '0.5891',
#    'high24h': '0.5984',
#    'low24h': '0.5395',
#    'volCcy24h': '1461568.7941168872',
#    'vol24h': '2581105.326077',
#    'ts': '1760125726117',
#    'sodUtc0': '0.5936',
#    'sodUtc8': '0.5572'},
#   {'instType': 'SPOT',
#    'instId': 'ZRO-USDT',
#    'last': '2.161',
#    'lastSz': '86.572',
#    'askPx': '2.161',
#    'askSz': '370.227',
#    'bidPx': '2.159',
#    'bidSz': '2673.504',
#    'open24h': '2.283',
#    'high24h': '2.32',
#    'low24h': '2.126',
#    'volCcy24h': '2497969.471994',
#    'vol24h': '1118774.334',
#    'ts': '1760125726518',
#    'sodUtc0': '2.276',
#    'sodUtc8': '2.168'}]}

# %%
crypto_scanner.calculate_trailing_stop("PEPE-USDT", bar='5m')
# Out:
# {'instId': 'PEPE-USDT',
#  'buy_price': 9.71e-06,
#  'current_price': 9.71e-06,
#  'atr_value': 4.499999999999969e-08,
#  'initial_stop_loss': 9.642500000000001e-06,
#  'trailing_stop_price': 9.642500000000001e-06,
#  'take_profit': 9.845e-06,
#  'stop_loss_multiplier': 1.5,
#  'take_profit_multiplier': 3.0}

# %%
# bullish_coins_1 = crypto_scanner.scan_ma_alignment(bar='5m', ma_periods=[5, 20, 60, 120])
print(f"total: {len(bullish_coins_1)}")
for coin in bullish_coins_1:
    print(coin.get("symbol"))
# Out:
# Scanning 114 symbols for MA convergence + breakout patterns

# %%
bullish_coins_2 = crypto_scanner.scan_ma_convergence_breakout(bar='5m')
print(f"total: {len(bullish_coins_2)}")
for i, coin in enumerate(bullish_coins_2):
    print(f'{i}: {coin.get("symbol")}')
    print(coin)

# print(bullish_coins_2)
# Out:
# Scanning 122 symbols for MA convergence + breakout patterns
# total: 0

# %%
bullish_coins_3 = crypto_scanner.scan_momentum_early(bar='5m')
print(f"total: {len(bullish_coins_3)}")
for coin in bullish_coins_3:
    print(coin.get("symbol"))
# Out:
# total: 0

# %%
bullish_coins_4 = crypto_scanner.scan_volume_breakout(bar='5m')
print(f"total: {len(bullish_coins_4)}")
for coin in bullish_coins_4:
    print(coin.get("symbol"))
# Out:
# total: 12
# ASP-USDT
# ETHW-USDT
# RAY-USDT
# MERL-USDT
# TURBO-USDT
# PYTH-USDT
# SKY-USDT
# ZK-USDT
# OKSOL-USDT
# SOL-USDT
# CFX-USDT
# SATS-USDT

# %%
bullish_coins_5 = crypto_scanner.scan_slope_acceleration(bar='5m')
print(f"total: {len(bullish_coins_5)}")
for coin in bullish_coins_5:
    print(coin.get("symbol"))
# Out:
# total: 0
